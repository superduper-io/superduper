# %%
from superduper import *

# %%
db = superduper('snowflake://softwareuser:SU4yv6DfUPUL0CPDdsCDDSLttVc@ngkjqqn-superduperdbeu/myuser_db/data')
# Out:
# 2025-Feb-27 12:55:48.92| INFO     | Duncans-MBP.fritz.box| superduper.misc.importing:13   | Loading plugin: snowflake
# [2025-02-27 12:55:49] snowflake.connector.connection INFO Snowflake Connector for Python Version: 3.13.2, Python Version: 3.10.13, Platform: macOS-14.1-arm64-arm-64bit
# [2025-02-27 12:55:49] snowflake.connector.connection INFO Connecting to GLOBAL Snowflake domain
# [2025-02-27 12:55:49] snowflake.connector.connection INFO This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# 2025-Feb-27 12:55:49.56| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.connect:10   | Creating Snowpark session for snowflake data-backend implementation
# [2025-02-27 12:55:50] snowflake.snowpark.session INFO Snowpark Session information:
# "version" : 1.27.0,
# "python.version" : 3.10.13,
# ...

# %%
from superduper.base.schema import Schema

s = Schema.build(b='str', c='int', d='json')

db.databackend.create_table_and_schema('test', s, 'id')
# Out:
# 2025-Feb-27 12:56:08.19| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:85   | Creating table with query:
# CREATE OR REPLACE HYBRID TABLE "test" (
#     "id" VARCHAR PRIMARY KEY,
#     "b" VARCHAR,
#     "c" NUMBER,
#     "d" VARIANT
# );
#
# 2025-Feb-27 12:56:09.66| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:87   | Creating table ... DONE

# %%
for i in range(100):
    db.databackend.insert('test', [{'b': 'test-b', 'c': 2, 'd': {'this': 'is d'}, 'id': f'{i + 100}'}], 'id')
# Out:
# 2025-Feb-27 13:02:22.64| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:205  | Inserting row with query:
# INSERT INTO "test" ("id", "b", "c", "d")
# VALUES
#     (100, NULL, NULL, NULL)
#
# 2025-Feb-27 13:02:22.73| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:207  | Inserting row... DONE
# 2025-Feb-27 13:02:22.78| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:205  | Inserting row with query:
# INSERT INTO "test" ("id", "b", "c", "d")
# VALUES
#     (101, NULL, NULL, NULL)
#
# 2025-Feb-27 13:02:22.97| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:207  | Inserting row... DONE
# 2025-Feb-27 13:02:23.03| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:205  | Inserting row with query:
# INSERT INTO "test" ("id", "b", "c", "d")
# VALUES
#     (102, NULL, NULL, NULL)
#
# ...

# %%
debug
# Out:
# > /Users/dodo/superduper-io/superduper/plugins/snowflake/superduper_snowflake/data_backend.py(197)_insert_row()
#     195                 to_insert.append(f'{r[f.name]}')
#     196         columns = ', '.join(columns)
# --> 197         to_insert = ', '.join(to_insert)
#     198         statement = insert_to_row.format(table=table, columns=columns, values=to_insert)
#     199         logging.info(f"Inserting row with query: {statement}")
# ipdb>  q

# %%
db.databackend.list_tables()

# %%
db.apply(
    Table(
        'test',
        fields={'x': 'str', 'y': 'float', 'z': 'bool'}
    )
)
