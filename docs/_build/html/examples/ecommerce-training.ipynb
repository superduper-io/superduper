# %%
from superduperdb.mongodb.client import SuperDuperClient
from IPython.display import display

c = SuperDuperClient()
docs = c.ecommerce.documents
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from superduperdb.mongodb.client import SuperDuperClient
#       2 from IPython.display import display
#       4 c = SuperDuperClient()
#
# ModuleNotFoundError: No module named 'superduperdb.mongodb'

# %%
import torch


class Target(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
    def preprocess(self, value):
        return torch.tensor(float(value))
    
    def forward(self, x):
        return x
    
    
class PersonDetector(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = torch.nn.Linear(1024, 1)
        
    def preprocess(self, value):
        return torch.tensor(value).type(torch.float)
    
    def forward(self, x):
        return self.linear(x)[:, 0]
    
    def postprocess(self, x):
        return x.item() > 0.5


docs.create_model(
    'target',
    Target(),
    serializer='dill',
)

docs.create_model(
    'person_detector',
    PersonDetector(),
    serializer='dill',
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 30
#      26     def postprocess(self, x):
#      27         return x.item() > 0.5
# ---> 30 docs.create_model(
#      31     'target',
#      32     Target(),
#      33     serializer='dill',
#      34 )
#      36 docs.create_model(
#      37     'person_detector',
#      38     PersonDetector(),
#      39     serializer='dill',
#      40 )
#
# NameError: name 'docs' is not defined

# %%
pos_weight = docs.count_documents({'person': True}) / docs.count_documents({'person': False})

docs.create_objective('bce', torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pos_weight = docs.count_documents({'person': True}) / docs.count_documents({'person': False})
#       3 docs.create_objective('bce', torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight)))
#
# NameError: name 'docs' is not defined

# %%
docs.create_metric('accuracy', lambda x, y: x == y, serializer='dill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 docs.create_metric('accuracy', lambda x, y: x == y, serializer='dill')
#
# NameError: name 'docs' is not defined

# %%
job_ids = docs.create_imputation(
    'person_imputation',
    'person_detector',
    '_base',
    'target',
    'person',
    objective='bce',
    metrics=['accuracy'],
    filter_={'person': {'$exists': 1}},
    trainer_kwargs={'features': {'_base': 'clip'}, 'log_interval': 50},
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 job_ids = docs.create_imputation(
#       2     'person_imputation',
#       3     'person_detector',
#       4     '_base',
#       5     'target',
#       6     'person',
#       7     objective='bce',
#       8     metrics=['accuracy'],
#       9     filter_={'person': {'$exists': 1}},
#      10     trainer_kwargs={'features': {'_base': 'clip'}, 'log_interval': 50},
#      11 )
#
# NameError: name 'docs' is not defined

# %%
job_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 job_ids
#
# NameError: name 'job_ids' is not defined

# %%
docs.watch_job(job_ids[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 docs.watch_job(job_ids[0])
#
# NameError: name 'docs' is not defined

# %%
docs.list_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 docs.list_models()
#
# NameError: name 'docs' is not defined

# %%
_id = next(docs.aggregate([
    {'$match': {}},
    {'$sample': {'size': 1}},
    {'$project': {'_id': 1}}
]))['_id']

r = docs.find_one({'_id': _id})

display(r['img'])
docs.apply_model('person_detector', r['_outputs']['_base']['clip'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 _id = next(docs.aggregate([
#       2     {'$match': {}},
#       3     {'$sample': {'size': 1}},
#       4     {'$project': {'_id': 1}}
#       5 ]))['_id']
#       7 r = docs.find_one({'_id': _id})
#       9 display(r['img'])
#
# NameError: name 'docs' is not defined

# %%
docs.delete_imputation('person_imputation', force=True)
docs.delete_objective('bce', force=True)
docs.delete_metric('accuracy', force=True)
docs.delete_model('person_detector', force=True)
docs.delete_model('target', force=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 docs.delete_imputation('person_imputation', force=True)
#       2 docs.delete_objective('bce', force=True)
#       3 docs.delete_metric('accuracy', force=True)
#
# NameError: name 'docs' is not defined
