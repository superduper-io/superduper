# %%
from superduper import *

# %%
db = superduper('snowflake://softwareuser:SU4yv6DfUPUL0CPDdsCDDSLttVc@ngkjqqn-superduperdbeu/myuser_db/data')
# Out:
# 2025-Feb-26 13:31:58.27| INFO     | Duncans-MBP.fritz.box| superduper.misc.importing:13   | Loading plugin: snowflake
# [2025-02-26 13:31:58] snowflake.connector.connection INFO Snowflake Connector for Python Version: 3.13.2, Python Version: 3.10.13, Platform: macOS-14.1-arm64-arm-64bit
# [2025-02-26 13:31:58] snowflake.connector.connection INFO Connecting to GLOBAL Snowflake domain
# [2025-02-26 13:31:58] snowflake.connector.connection INFO This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# 2025-Feb-26 13:31:58.69| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.connect:10   | Creating Snowpark session for snowflake data-backend implementation
# [2025-02-26 13:31:59] snowflake.snowpark.session INFO Snowpark Session information:
# "version" : 1.27.0,
# "python.version" : 3.10.13,
# "python.connector.version" : 3.13.2,
# "python.connector.session.id" : 406398414278914,
# "os.name" : Darwin
# 2025-Feb-26 13:31:59.27| INFO     | Duncans-MBP.fritz.box| superduper.base.datalayer:50   | Building Data Layer
# 2025-Feb-26 13:31:59.28| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:75   | Creating table with query:
# CREATE OR REPLACE HYBRID TABLE "Table" (
#     "uuid" VARCHAR PRIMARY KEY,
#     "identifier" VARCHAR,
#     "upstream" VARIANT,
#     "cache" BOOLEAN,
#     "status" VARCHAR,
#     "build_variables" VARIANT,
#     "build_template" VARCHAR,
#     "fields" VARIANT,
#     "primary_id" VARCHAR,
#     "data" VARCHAR,
#     "path" VARCHAR,
#     "component" BOOLEAN,
#     "version" NUMBER
# );
#
# 2025-Feb-26 13:31:59.77| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:77   | Creating table ... DONE
# 2025-Feb-26 13:31:59.77| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:75   | Creating table with query:
# CREATE OR REPLACE HYBRID TABLE "ParentChildAssociations" (
#     "uuid" VARCHAR PRIMARY KEY,
#     "parent_component" VARCHAR,
#     "parent_uuid" VARCHAR,
#     "child_component" VARCHAR,
#     "child_uuid" VARCHAR
# );
#
# 2025-Feb-26 13:32:00.18| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:77   | Creating table ... DONE
# 2025-Feb-26 13:32:00.18| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:75   | Creating table with query:
# CREATE OR REPLACE HYBRID TABLE "ArtifactRelations" (
#     "uuid" VARCHAR PRIMARY KEY,
#     "component_id" VARCHAR,
#     "artifact_id" VARCHAR
# );
#
# 2025-Feb-26 13:32:00.70| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:77   | Creating table ... DONE
# 2025-Feb-26 13:32:00.70| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:75   | Creating table with query:
# CREATE OR REPLACE HYBRID TABLE "Job" (
#     "job_id" VARCHAR PRIMARY KEY,
#     "context" VARCHAR,
#     "component" VARCHAR,
#     "identifier" VARCHAR,
#     "args" VARIANT,
#     "kwargs" VARIANT,
#     "time" VARCHAR,
#     "method" VARCHAR,
#     "status" VARCHAR,
#     "dependencies" VARIANT
# );
#
# 2025-Feb-26 13:32:01.12| INFO     | Duncans-MBP.fritz.box| superduper_snowflake.data_backend:77   | Creating table ... DONE
# 2025-Feb-26 13:32:01.12| INFO     | Duncans-MBP.fritz.box| superduper.base.datalayer:67   | Data Layer built
# 2025-Feb-26 13:32:06.39| INFO     | Duncans-MBP.fritz.box| superduper.backends.base.cluster:113  | Cluster initialized in 5.27 seconds.
# 2025-Feb-26 13:32:06.40| INFO     | Duncans-MBP.fritz.box| superduper.base.build:146  | Configuration:
#  +----------------+-------------------------------------------------------------------------+
# | Configuration  |                                  Value                                  |
# +----------------+-------------------------------------------------------------------------+
# |  Data Backend  | snowflake://so******er:SU******Vc@ngkjqqn-superduperdbeu/myuser_db/data |
# | Artifact Store |                      filesystem://./artifact_store                      |
# +----------------+-------------------------------------------------------------------------+

# %%
from superduper.base.schema import Schema

s = Schema.build(b='str', c='int', d='json')

db.databackend.create_table_and_schema('test', s, 'id')

# %%
db.databackend.insert('test', [{'b': 'test-b', 'c': 2, 'd': {'this': 'is d'}}], 'id')

# %%
db.databackend.list_tables()

# %%
db.apply(
    Table(
        'test',
        fields={'x': 'str', 'y': 'float', 'z': 'bool'}
    )
)
